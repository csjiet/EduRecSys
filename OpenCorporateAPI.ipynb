# %% [markdown]
# # OpenCorporate API
# API Documentation: https://api.opencorporates.com/documentation/API-Reference

# %%
# !python -m pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
load_dotenv()

API_KEY = os.getenv("OPENCORPORATES_API_KEY")
BASE_URL = "https://api.opencorporates.com/v0.4"

# %%
import requests

# The above endpoints return a number of results, which are paginated. By default 30 objects are returned, together with the current page number, and the total number of pages. Returning results for a specific page is possible using the following parameters:
def get_company(state):
    # url = f"{BASE_URL}/companies/{jurisdiction_code}/{company_number}?api_token={API_KEY}"
    # url = f"{BASE_URL}/companies/{jurisdiction_code}/?api_token={API_KEY}"
    url = f"{BASE_URL}/companies/search?jurisdiction_code=us_{state}&api_token={API_KEY}"
    response = requests.get(url)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

state = "in"
# example usage
company_data = get_company(state)
print(company_data)
# Out:
# {'api_version': '0.4', 'results': {'companies': [{'company': {'name': '!!AY WEY!! TACOS LLC', 'company_number': '202301171655407', 'jurisdiction_code': 'us_in', 'incorporation_date': '2023-01-17', 'dissolution_date': None, 'company_type': 'Domestic Limited Liability Company', 'registry_url': 'https://bsd.sos.in.gov/publicbusinesssearch', 'branch': None, 'branch_status': None, 'inactive': False, 'current_status': 'Active', 'created_at': '2023-03-03T00:10:11+00:00', 'updated_at': '2025-02-03T23:45:51+00:00', 'retrieved_at': '2025-01-01T00:00:00+00:00', 'opencorporates_url': 'https://opencorporates.com/companies/us_in/202301171655407', 'previous_names': [], 'alternative_names': [], 'source': {'publisher': 'Indiana Secretary of State', 'url': 'https://inbiz.in.gov/Inbiz/BulkDataServices', 'retrieved_at': '2025-01-01T00:00:00+00:00'}, 'registered_address': None, 'registered_address_in_full': None, 'industry_codes': [], 'restricted_for_marketing': None, 'native_company_number': None}}, {'company': {'name': '!AY CARAY! NUTRITION, LLC', 'company_number': '202308301720824', 'jurisdiction_code': 'us_in', 'incorporation_date': '2023-08-30', 'dissolution_date': None, 'company_type': 'Domestic Limited Liability Company', 'registry_url': 'https://bsd.sos.in.gov/publicbusinesssearch', 'branch': None, 'branch_status': None, 'inactive': False, 'current_status': 'Active', 'created_at': '2023-10-03T01:31:18+00:00', 'updated_at': '2025-02-04T00:59:11+00:00', 'retrieved_at': '2025-01-01T00:00:00+00:00', 'opencorporates_url': 'https://opencorporates.com/companies/us_in/202308301720824', 'previous_names': [], 'alternative_names': [], 'source': {'publisher': 'Indiana Secretary of State', 'url': 'https://inbiz.in.gov/Inbiz/BulkDataServices', 'retrieved_at': '2025-01-01T00:00:00+00:00'}, 'registered_address': None, 'registered_address_in_full': None, 'industry_codes': [], 'restricted_for_marketing': None, 'native_company_number': None}}, {'company': {'name': "!ELI'S COMPUTER REPAIR AND SERVICE LLC", 'company_number': '202102241464903', 'jurisdiction_code': 'us_in', 'incorporation_date': '2021-02-24', 'dissolution_date': '2022-05-11', 'company_type': 'Domestic Limited Liability Company', 'registry_url': 'https://bsd.sos.in.gov/publicbusinesssearch', 'branch': None, 'branch_status': None, 'inactive': True, 'current_status': 'Voluntarily Dissolved', 'created_at': '2021-04-17T20:27:57+00:00', 'updated_at': '2023-05-23T13:27:50+00:00', 'retrieved_at': '2023-03-02T00:00:00+00:00', 'opencorporates_url': 'https://opencorporates.com/companies/us_in/202102241464903', 'previous_names': [{'company_name': "!ELI'S COMPUTER REPAIR AND SERVICE LLC"}], 'alternative_names': [], 'source': {'publisher': 'Indiana Secretary of State', 'url': 'https://inbiz.in.gov/Inbiz/BulkDataServices', 'retrieved_at': '2023-03-02T00:00:00+00:00'}, 'registered_address': None, 'registered_address_in_full': None, 'industry_codes': [], 'restricted_for_marketing': None, 'native_company_number': None}}, {'company': {'name': '!XIMML! LLC', 'company_number': '202103221473045', 'jurisdiction_code': 'us_in', 'incorporation_date': '2021-03-22', 'dissolution_date': None, 'company_type': 'Domestic Limited Liability Company', 'registry_url': 'https://bsd.sos.in.gov/publicbusinesssearch', 'branch': None, 'branch_status': None, 'inactive': False, 'current_status': 'Active', 'created_at': '2021-04-17T20:44:20+00:00', 'updated_at': '2023-05-23T13:36:10+00:00', 'retrieved_at': '2023-03-02T00:00:00+00:00', 'opencorporates_url': 'https://opencorporates.com/companies/us_in/202103221473045', 'previous_names': [], 'alternative_names': [], 'source': {'publisher': 'Indiana Secretary of State', 'url': 'https://inbiz.in.gov/Inbiz/BulkDataServices', 'retrieved_at': '2023-03-02T00:00:00+00:00'}, 'registered_address': None, 'registered_address_in_full': None, 'industry_codes': [], 'restricted_for_marketing': None, 'native_company_number': None}}, {'company': {'name': '" LAS FUENTES " INC.', 'company_number': '200312300 ...

# %%
import json
with open(f"OpenCorporateJSON_{state.upper()}.json", "w") as file:
    json.dump(company_data, file)

# %%
import pandas as pd
from pprint import pprint
j_file = json.dumps(company_data, indent=2)
res = json.loads(j_file)
pprint(len(res["results"]["companies"]))
df = pd.DataFrame(res["results"]["companies"])
# Out:
# 30

# %%
import pandas as pd
df_expanded = df["company"].apply(pd.Series)

# Concatenate the expanded columns with the original DataFrame ,dropping 'company' column
df_final = pd.concat([df_expanded, df.drop(columns=["company"])], axis=1)
print(f"Total rows: {len(df_final)}")
df_final.head()
# Out:
# Total rows: 30
#                                      name   company_number jurisdiction_code  \
# 0                    !!AY WEY!! TACOS LLC  202301171655407             us_in
# 1               !AY CARAY! NUTRITION, LLC  202308301720824             us_in
# 2  !ELI'S COMPUTER REPAIR AND SERVICE LLC  202102241464903             us_in
# 3                             !XIMML! LLC  202103221473045             us_in
# 4                    " LAS FUENTES " INC.    2003123000508             us_in
#
#   incorporation_date dissolution_date                        company_type  \
# 0         2023-01-17             None  Domestic Limited Liability Company
# 1         2023-08-30             None  Domestic Limited Liability Company
# 2         2021-02-24       2022-05-11  Domestic Limited Liability Company
# 3         2021-03-22             None  Domestic Limited Liability Company
# 4         2003-12-30       2008-07-18     Domestic For-Profit Corporation
#
#                                         registry_url branch branch_status  \
# 0        https://bsd.sos.in.gov/publicbusinesssearch   None          None
# 1        https://bsd.sos.in.gov/publicbusinesssearch   None          None
# 2        https://bsd.sos.in.gov/publicbusinesssearch   None          None
# 3        https://bsd.sos.in.gov/publicbusinesssearch   None          None
# 4  https://bsd.sos.in.gov/PublicBusinessSearch/Bu...   None          None
#
#    inactive  ...               retrieved_at  \
# 0     False  ...  2025-01-01T00:00:00+00:00
# 1     False  ...  2025-01-01T00:00:00+00:00
# 2      True  ...  2023-03-02T00:00:00+00:00
# 3     False  ...  2023-03-02T00:00:00+00:00
# 4      True  ...  2023-03-02T00:00:00+00:00
#
#                                   opencorporates_url  \
# 0  https://opencorporates.com/companies/us_in/202...
# 1  https://opencorporates.com/companies/us_in/202...
# 2  https://opencorporates.com/companies/us_in/202...
# 3  https://opencorporates.com/companies/us_in/202...
# 4  https://opencorporates.com/companies/us_in/200...
#
#                                       previous_names alternative_names  \
# 0                                                 []                []
# 1                                                 []                []
# 2  [{'company_name': '!ELI'S COMPUTER REPAIR AND ...                []
# 3                                                 []                []
# 4         [{'company_name': '" LAS FUENTES " INC.'}]                []
#
#                                               source  \
# 0  {'publisher': 'Indiana Secretary of State', 'u...
# 1  {'publisher': 'Indiana Secretary of State', 'u...
# 2  {'publisher': 'Indiana Secretary of State', 'u...
# 3  {'publisher': 'Indiana Secretary of State', 'u...
# 4  {'publisher': 'Indiana Secretary of State', 'u...
#
#                                   registered_address  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'street_address': '304 KNOLL CIRCLE #G, CRAWF...
#
#                       registered_address_in_full industry_codes  \
# 0                                           None             []
# 1                                           None             []
# 2                                           None             []
# 3                                           None             []
# 4  304 KNOLL CIRCLE #G, CRAWFORDSVILLE, IN 47933             []
#
#   restricted_for_marketing native_company_number
# 0                     None                  None
# 1                     None                  None
# 2                     None                  None
# 3                     None                  None
# 4                     None                  None
#
# [5 rows x 23 columns]

# %%
df_final.to_csv(f"companies_{state}.csv")
